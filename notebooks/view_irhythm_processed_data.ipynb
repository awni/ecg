# %%
import sys
sys.path.append("../")
import loader
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data_path = "/deep/group/med/irhythm/ecg/extracted_clean_5min_recs"
batch_size = 32
ldr = loader.Loader(data_path, batch_size)
# Out:
# [(u'AFIB', 924), (u'NSR', 704), (u'VT', 292), (u'AVB_TYPE2', 130), ('PAUSE', 49), (u'BIGEMINY', 10), (u'TRIGEMINY', 8), (u'SVT', 3)]

# %%
idx = 0
example = ldr.train[idx][0]
plt.plot(ldr.train[idx][0])
print "Label is", ldr.train[idx][1]
# Out:
# <img src="data:image/png;base64,...">
# Label is AFIB

# %%
label = 'BIGEMINY' #'SVT'
for e, (ex, l) in enumerate(ldr.train):
    if l == label:
        print e
# Out:
# 152
# 486
# 942
# 1352
# 1503
# 1575
# 1802
# 1882
# 2026
# 2032
